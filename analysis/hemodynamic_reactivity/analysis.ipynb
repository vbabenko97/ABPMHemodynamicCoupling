# %% [markdown]
# # Task reactivity in this ABPM cohort is primarily a physical-stage SBP and HR phenomenon, with the clearest participant-level signals coming from lower nocturnal dipping, smaller battery-2 Stroop interference, and a directional increase with BP load.

# %% [markdown]
# Prepared for Scientists on 2026-04-17.
#
# This notebook mirrors the markdown report and keeps the code required to reproduce the key figures inline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
# %matplotlib inline
root = Path('analysis/hemodynamic_reactivity')
agg = pd.read_csv(root / 'data' / 'aggregated_data.csv').rename(columns={'avg_reaction_time_battey_2':'avg_reaction_time_battery_2'})

# %% [markdown]
# ## Physical tasks produce the main hemodynamic excursion in this cohort
#
# Physical tasks lift SBP and HR more than cognitive tasks, making modality the first-order framing signal.

# %%
from IPython.display import Image, display
display(Image(filename=str(root / 'charts/01_physical_vs_cognitive.png')))

# %% [markdown]
# ## The modality gap is a stage-2 SBP and HR effect, not a uniform rise across all channels
#
# The modality gap is a stage-2 effect rather than a uniform elevation across all stages and channels.

# %%
from IPython.display import Image, display
display(Image(filename=str(root / 'charts/02_stage_specific_reactivity.png')))

# %% [markdown]
# ## Higher BP load and lower nocturnal dipping concentrate the strongest physical responders
#
# BP load and nocturnal dipping show where the strongest physical responders cluster.

# %%
from IPython.display import Image, display
display(Image(filename=str(root / 'charts/03_reactivity_vs_load_and_dipping.png')))

# %% [markdown]
# ## Participants with smaller battery-2 Stroop interference show stronger physical-task reactivity
#
# Battery-2 Stroop interference is inversely related to physical-task reactivity.

# %%
from IPython.display import Image, display
display(Image(filename=str(root / 'charts/04_stroop_vs_physical_reactivity.png')))

# %% [markdown]
# ## Diagnostic status separates baseline load and battery-2 performance more than task-reactivity magnitude
#
# Health status separates baseline phenotype more than task-reactivity magnitude.

# %%
from IPython.display import Image, display
display(Image(filename=str(root / 'charts/05_health_status_contrasts.png')))

# %% [markdown]
# ## Recommendations
#
# - **R1** Prioritize physical-task SBP and HR endpoints, especially stage 2, as the primary physiological readouts in the next mechanistic study. (High confidence; follow-up 2026-06-15)
# - **R2** Stratify future analyses by nocturnal SBP dipping and ABPM load before aggregating task responses. (Medium confidence; follow-up 2026-06-15)
# - **R3** Test whether battery-2 Stroop interference is a surrogate of preserved autonomic reserve rather than a marker of dysregulation. (Medium confidence; follow-up 2026-07-01)

# %% [markdown]
# ## How To Reproduce
#
# Run `python analysis/hemodynamic_reactivity/notebooks/01_profile.py` through `06_deliver.py` in order from the repository root.
